# %%
import numpy as np
import pandas as pd
import math
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import (Dense, Dropout,
                                    Activation, Flatten,
                                    MaxPooling2D, SimpleRNN)
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From D:\New folder\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
n_steps = 13
n_features = 1

# %%
model = Sequential()
model.add(SimpleRNN(512, activation='relu',
                   input_shape=(n_steps, n_features),
                   return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='linear'))

# %%
model.compile(optimizer='rmsprop',
loss = 'mse',
metrics = ['mse'])
# Out:
# WARNING:tensorflow:From D:\New folder\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
def split_sequence(sequence, n_steps):
    X,y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
        return np.array(X), np.array(y)

# %%
Square = pd.read_csv("C:/Users/dell/Desktop/Square.csv")
Square['Date'] = pd.to_datetime(Square['Date'])
Square.set_index('Date', inplace=True)
Square = pd.to_numeric(Square['Close'])
Square
# Out:
# Date
# 2024-01-01    209.80
# 2023-12-01    210.30
# 2023-11-01    209.80
# 2023-10-01    211.10
# 2023-09-01    209.80
# 2023-08-01    211.10
# 2023-07-01    209.80
# 2023-06-01    209.80
# 2023-05-01    209.80
# 2023-04-01    209.80
# 2023-03-01    209.80
# 2023-02-01    209.80
# 2023-01-01    209.80
# 2022-12-01    209.80
# 2022-11-01    209.81
# 2022-10-01    209.80
# 2022-09-01    209.80
# 2022-08-01    211.10
# 2022-07-01    208.90
# 2022-06-01    216.70
# 2022-05-01    216.10
# 2022-04-01    225.50
# 2022-03-01    219.30
# 2022-02-01    219.10
# 2022-01-01    220.20
# 2021-12-01    214.30
# 2021-11-01    211.80
# 2021-10-01    217.70
# 2021-09-01    242.20
# 2021-08-01    226.60
# 2021-07-01    222.00
# 2021-06-01    215.50
# 2021-05-01    213.00
# 2021-04-01    211.80
# 2021-03-01    196.60
# 2021-02-01    214.80
# 2021-01-01    236.20
# 2020-12-01    219.50
# 2020-11-01    183.90
# 2020-10-01    188.95
# 2020-09-01    194.29
# 2020-08-01    208.48
# 2020-07-01    172.38
# ...

# %%
diff_stock_prices = Square.diff().dropna()

# %%
split = int(len(diff_stock_prices.values) * 0.95)
diff_train_Square = diff_stock_prices.iloc[:split]
diff_test_Square = diff_stock_prices.iloc[split:]

# %%
X_Square,y_Square= split_sequence(diff_train_Square,n_steps)
X_Square1=X_Square

history = model.fit(X_Square, y_Square,
                   epochs=400, batch_size=150, verbose=0,
                   validation_split= 0)

start = X_Square[X_Square.shape[1] - n_steps]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

tempList_Square = []
for i in range(len(diff_test_Square)):
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_Square.append(yhat)

# %%
fig, ax = plt.subplots(2,1, figsize=(18,15))
ax[0].plot(diff_test_Square, label='Actual Stock Price', linestyle='--')
ax[0].plot(diff_test_Square.index, np.array(tempList_Square).flatten(),
          linestyle='solid',label='Prediction')
ax[0].set_title('Predicted Stock Price-Square')
ax[0].legend(loc='best')

for ax in ax.flat:
    ax.set(xlabel='Date', ylabel='$')
plt.show()

# %%
from tensorflow.keras.layers import LSTM
n_steps = 13
n_features = 1
model = Sequential()
model.add(LSTM(512, activation='relu',
              input_shape=(n_steps, n_features),
              return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256, activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='linear'))
model.compile(optimizer='rmsprop', loss='mse',
             metrics=['mse'])
history = model.fit(X_Square, y_Square, 400, 150, 0,
                    validation_split=0)

start = X_Square[X_Square.shape[1] - 13]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

tempList_Square = []
for i in range(len(diff_test_Square)):
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_Square.append(yhat)
    
fig, ax = plt.subplots(2,1, figsize=(18,15))
ax[0].plot(diff_test_Square, label='Actual Stock Price', linestyle='--')
ax[0].plot(diff_test_Square.index, np.array(tempList_Square).flatten(),
          linestyle='solid',label='Prediction')
ax[0].set_title('Predicted Stock Price-Square')
ax[0].legend(loc='best')

for ax in ax.flat:
    ax.set(xlabel='Date', ylabel='$')
plt.show()
