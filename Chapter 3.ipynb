# %%
import numpy as np
import pandas as pd
import math
import datetime
import yfinance as yf
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import (Dense, Dropout,
                                      Activation, Flatten,
                                      MaxPooling2D, SimpleRNN)
from sklearn.model_selection import train_test_split

# %%
n_steps = 13
n_features = 1

# %%
model = Sequential()
model.add(SimpleRNN(512, activation='relu',
                     input_shape=(n_steps, n_features),
                     return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(256, activation = 'relu'))
model.add(Flatten())
model.add(Dense(1, activation='linear'))
# Out:
# WARNING:tensorflow:From D:\New folder\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.compile(optimizer='rmsprop',
loss='mse',
metrics=['mse'])
# Out:
# WARNING:tensorflow:From D:\New folder\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
def split_sequence(sequence, n_steps):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
             break
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    X.append(seq_x)
    y.append(seq_y)
    return np.array(X), np.array(y)

# %%
ticker = ['AAPL', 'MSFT']
start = datetime.datetime(2019, 1, 1)
end = datetime.datetime(2020, 1 ,1)
stock_prices = yf.download(ticker,start=start, end = end, interval='1d')\
                             .Close
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
diff_stock_prices = stock_prices.diff().dropna()

# %%
split = int(len(diff_stock_prices['AAPL'].values) * 0.95)
diff_train_aapl = diff_stock_prices['AAPL'].iloc[:split]
diff_test_aapl = diff_stock_prices['AAPL'].iloc[split:]
diff_train_msft = diff_stock_prices['MSFT'].iloc[:split]
diff_test_msft = diff_stock_prices['MSFT'].iloc[split:]

# %%
X_aapl, y_aapl = split_sequence(diff_train_aapl, n_steps)
X_aapl = X_aapl.reshape((X_aapl.shape[0], X_aapl.shape[0],
                         n_features))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 X_aapl, y_aapl = split_sequence(diff_train_aapl, n_steps)
#       2 X_aapl = X_aapl.reshape((X_aapl.shape[0], X_aapl.shape[0],
#       3                          n_features))
#
# Cell In[7], line 7, in split_sequence(sequence, n_steps)
#       5     if end_ix > len(sequence) - 1:
#       6          break
# ----> 7 seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
#       8 X.append(seq_x)
#       9 y.append(seq_y)
#
# File D:\New folder\Lib\site-packages\pandas\core\series.py:978, in Series.__getitem__(self, key)
#     975     key = unpack_1tuple(key)
#     977 if is_integer(key) and self.index._should_fallback_to_positional:
# --> 978     return self._values[key]
#     980 elif key_is_scalar:
#     981     return self._get_value(key)
#
# IndexError: index 238 is out of bounds for axis 0 with size 238

# %%
def split_sequence(sequence, n_steps):
    X, y = [], []
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

ticker = ['AAPL', 'MSFT']
start = datetime.datetime(2019,1,1)
end= datetime.datetime(2020,1,1)
stock_prices = yf.download(ticker,start=start,end=end,interval="1d")['Close']

diff_stock_prices = stock_prices.diff().dropna()

split = int(len(diff_stock_prices['AAPL'].values) * 0.95)
diff_train_aapl= diff_stock_prices['AAPL'].iloc[:split]
diff_test_aapl= diff_stock_prices['AAPL'].iloc[split:]
diff_train_msft= diff_stock_prices['MSFT'].iloc[:split]
diff_test_msft= diff_stock_prices['MSFT'].iloc[split:]

X_aapl,y_aapl= split_sequence(diff_train_aapl,n_steps)
X_aap1=X_aapl

history = model.fit(X_aapl, y_aapl,
                   epochs=400, batch_size=150, verbose=0,
                   validation_split= 0.10)

start = X_aapl[X_aapl.shape[0] - n_steps]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

tempList_aapl = []
for i in range(len(diff_test_aapl)):
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_aapl.append(yhat)

X_msft,y_msft= split_sequence(diff_train_msft,n_steps)
X_msft1=X_msft

history = model.fit(X_msft, y_msft,
                   epochs=400, batch_size=150, verbose=0,
                   validation_split= 0.10)

start = X_msft[X_msft.shape[0] - n_steps]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

tempList_msft = []
for i in range(len(diff_test_msft)):
    x_input = x_input.reshape((1, n_steps, n_features))  # Corrected this line
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_msft.append(yhat)
# Out:
# [*********************100%***********************]  2 of 2 completed
# WARNING:tensorflow:From D:\New folder\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From D:\New folder\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
fig, ax = plt.subplots(2,1, figsize=(18,15))
ax[0].plot(diff_test_aapl, label='Actual Stock Price', linestyle='--')
ax[0].plot(diff_test_aapl.index, np.array(tempList_aapl).flatten(),
linestyle='solid', label="Prediction")
ax[0].set_title('Predicted Stock Price-Apple')
ax[0].legend(loc='best')
ax[1].plot(diff_test_msft, label='Actual Stock Price', linestyle='--')
ax[1].plot(diff_test_msft.index,np.array(tempList_msft).flatten(),
linestyle='solid', label="Prediction")
ax[1].set_title('Predicted Stock Price-Microsoft')
ax[1].legend(loc='best')
for ax in ax.flat:
    ax.set(xlabel='Date', ylabel='$')
plt.show()

# %%
from tensorflow.keras.layers import LSTM

# %%
n_steps = 13
n_features = 1

# %%
model = Sequential()
model.add(LSTM(512, activation='relu',
              input_shape=(n_steps, n_features),
              return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256, activation='relu'))
model.add(Flatten())
model.add(Dense(1, activation='linear'))

# %%
model.compile(optimizer='rmsprop', loss='mse',
             metrics=['mse'])

# %%
history = model.fit(X_aapl, y_aapl, 400, 150, 0,
                    validation_split=0.10)

# %%
start = X_aapl[X_aapl.shape[0] - 13]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

# %%
tempList_aapl = []
for i in range(len(diff_test_aapl)):
    x_input = x_input.reshape((1, n_steps, n_features))
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_aapl.append(yhat)

# %%
history = model.fit(X_msft, y_msft, 400, 150, 0,
                    validation_split=0.10)

# %%
start = X_msft[X_msft.shape[0] - 13]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

# %%
X_msft,y_msft= split_sequence(diff_train_msft,n_steps)
X_msft1=X_msft

history = model.fit(X_msft, y_msft,
                   epochs=400, batch_size=150, verbose=0,
                   validation_split= 0.10)

start = X_msft[X_msft.shape[0] - n_steps]
x_input = start
x_input = x_input.reshape((1, n_steps, n_features))

tempList_msft = []
for i in range(len(diff_test_msft)):
    x_input = x_input.reshape((1, n_steps, n_features))  # Corrected this line
    yhat = model.predict(x_input, verbose=0)
    x_input = np.append(x_input, yhat)
    x_input = x_input[1:]
    tempList_msft.append(yhat)

# %%
fig, ax = plt.subplots(2,1, figsize=(18,15))
ax[0].plot(diff_test_aapl, label='Actual Stock Price', linestyle='--')
ax[0].plot(diff_test_aapl.index, np.array(tempList_aapl).flatten(),
          linestyle='solid',label='Prediction')
ax[0].set_title('Predicted Stock Price-Apple')
ax[0].legend(loc='best')
ax[1].plot(diff_test_msft, label='Actual Stock Price', linestyle='--')
ax[1].plot(diff_test_msft.index, np.array(tempList_msft).flatten(),
          linestyle='solid', label="Prediction")
ax[1].set_title('Predicted Stock Price-Microsoft')
ax[1].legend(loc='best')

for ax in ax.flat:
    ax.set(xlabel='Date', ylabel='$')
plt.show()
